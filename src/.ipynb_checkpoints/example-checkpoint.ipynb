# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.plotly as py
from plotly.offline import iplot, plot

# %%
from CarFactory import CarFactory
from Street import Street, StreetRamp, StreetAuto
from Constants import *

# %%
prob_auto, prob_car = .5, .5
num_lane = 3
road_length = 500 # 5 km
flow_in = 20 # vehicle per second

# %%
cf = CarFactory(prob_auto, prob_car)
road = Street(num_lane, road_length, cf)
for i in range(1000):
    road.update(flow_in)
    
    if i % 100 == 0:
        road.report()
# Out:
# -----------------------------------------------------------------
# time =  0.50
# total vehicle:    3, average speed 26.11, flow in 0.00 vehicle/s, flow out 0.00 vehicle/s
# 	 num cars in each lane [1. 1. 1.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 50.50
# total vehicle:   88, average speed 12.26, flow in 0.00 vehicle/s, flow out 0.00 vehicle/s
# 	 num cars in each lane [26. 31. 31.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 100.50
# total vehicle:  118, average speed 8.41, flow in 2.18 vehicle/s, flow out 1.58 vehicle/s
# 	 num cars in each lane [43. 40. 35.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 150.50
# total vehicle:  126, average speed 9.37, flow in 2.18 vehicle/s, flow out 1.58 vehicle/s
# 	 num cars in each lane [44. 39. 43.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.50
# total vehicle:  124, average speed 9.86, flow in 2.54 vehicle/s, flow out 2.54 vehicle/s
# 	 num cars in each lane [45. 38. 41.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 250.50
# total vehicle:  123, average speed 9.91, flow in 2.54 vehicle/s, flow out 2.54 vehicle/s
# 	 num cars in each lane [38. 44. 41.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.50
# total vehicle:  123, average speed 9.36, flow in 2.54 vehicle/s, flow out 2.52 vehicle/s
# 	 num cars in each lane [39. 43. 41.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 350.50
# total vehicle:  116, average speed 8.47, flow in 2.54 vehicle/s, flow out 2.52 vehicle/s
# 	 num cars in each lane [43. 32. 41.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.50
# total vehicle:  138, average speed 10.28, flow in 2.40 vehicle/s, flow out 1.94 vehicle/s
# 	 num cars in each lane [46. 44. 48.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 450.50
# total vehicle:  135, average speed 9.47, flow in 2.40 vehicle/s, flow out 1.94 vehicle/s
# 	 num cars in each lane [46. 44. 45.]
# -----------------------------------------------------------------

# %%
import plotly.graph_objs as go
color_map = dict()
color_map['0'] = 'rgb(255, 0, 0)'
color_map['1'] = 'rgb(204, 204, 0)'
color_map['2'] = 'rgb(0, 255, 0)'
color_map['3'] = 'rgb(0, 204, 204)'
color_map['4'] = 'rgb(0, 0, 255)'

def generate_fig(road):
    '''
    Input:
        street = list of "Moveable" --> Car or CarHuman
    Return:
        plolty fig
    '''
    lane_width = 5 # 5 m
    traces = []
    for car in road.street:
        trace = go.Scatter(x = [car.pos, car.pos+car.length],
                           y = [car.lane + 1, car.lane + 1],
                           mode = 'lines',
                           marker = dict( color = color_map['{}'.format(int(car.vel / (5.5)))]
                                           ))
        traces.append(trace)
    layout = go.Layout(title='traffic simulation at time {:6.1f}s'.format(road.time),
                       xaxis=dict(title='distance (meters)'),
                       yaxis=dict(title='lane number',
                                    showgrid=True,
                                    zeroline=False,
                                    showline=False,
                                    showticklabels=True),
                       showlegend=False)
    return go.Figure(data= traces, layout=layout)

# %%
fig = generate_fig(road)

# %%
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~horacehxw2/218.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Experiment 1: base line
# use the media of traffic flow per lane of the given dataset as our target traffic flow.
#
# * auto_prob = 0
#
# * car_prob = 0.8
#
# * speed_limit = 60 MPH = 96 KMH
#
# * flow_in = 1.31 v/s = 4725 v/h
#
# * flow_in_ramp = 0.44 v/s = 1575 v/h
#
# * flow_in_total = 1.75 v/s = 6300 v/h
#
# * mile_post_dist = 0.821 mile = 1.31 km
#
# simulation 1 hour to see a tyical rush hour in the morning or afternoon.
#
# **Taeget:** average speed of average speed in each time step.
#
# **Result:** v = 5.25 m/s = 18.9 KMH

# %%
import pandas as pd

# %%
data = pd.read_csv('../../../data/2017_MCM_Problem_C_Data.csv')

# %%
data['mile post'] = data['endMilepost'] - data['startMilepost']
data['ratio'] = data['Average daily traffic counts Year_2015'] / (data['Number of Lanes DECR MP direction '] + data['Number of Lanes INCR MP direction'])

# %%
data.head()
# Out:
#    Route_ID  startMilepost  endMilepost  \
# 0         5         100.93       101.87
# 1         5         101.87       103.17
# 2         5         103.17       103.42
# 3         5         103.42       104.81
# 4         5         104.81       105.63
#
#    Average daily traffic counts Year_2015  \
# 0                                   65000
# 1                                   85000
# 2                                  108000
# 3                                  101000
# 4                                  144000
#
#   RteType (IS= Interstate, SR= State Route)  \
# 0                                        IS
# 1                                        IS
# 2                                        IS
# 3                                        IS
# 4                                        IS
#
#    Number of Lanes DECR MP direction   Number of Lanes INCR MP direction  \
# 0                                   3                                  3
# 1                                   3                                  3
# 2                                   3                                  3
# 3                                   3                                  3
# 4                                   3                                  4
#
#                Comments  mile post         ratio
# 0               Olympia       0.94  10833.333333
# 1                   NaN       1.30  14166.666667
# 2                   NaN       0.25  18000.000000
# 3                   NaN       1.39  16833.333333
# 4  Rte 101 intersection       0.82  20571.428571

# %%
prob_auto, prob_car = 0, 0.8
flow_in = 1.31
road_length = 1310
dt = 0.5
prob_ramp = 0.25
num_lane = 3

cf = CarFactory(prob_auto, prob_car)
road = StreetRamp(num_lane, road_length, cf, prob_ramp, dt=dt)
speed_avg = []

for i in range(1, int(3600 / dt)):
    road.update(flow_in)
    speed_avg.append(np.mean([car.vel for car in road.street]))
    if i % 100 == 0:
        road.report()
#     if i % 400 == 0:
#         fig = generate_fig(road)
#         plot(fig, image='png', filename='image{:04d}.html'.format(int(i/400)), image_filename='image{:04d}'.format(int(i/400)))
# Out:
# -----------------------------------------------------------------
# time = 50.00
# total vehicle:   99, average speed 7.02, flow in 0.00 vehicle/s, flow out 0.00 vehicle/s
# 	 num cars in each lane [18. 21. 23. 37.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:  183, average speed 5.46, flow in 1.84 vehicle/s, flow out 0.16 vehicle/s
# 	 num cars in each lane [34. 40. 49. 60.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 150.00
# total vehicle:  273, average speed 5.31, flow in 1.84 vehicle/s, flow out 0.16 vehicle/s
# 	 num cars in each lane [47. 61. 72. 93.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  362, average speed 5.26, flow in 1.86 vehicle/s, flow out 0.08 vehicle/s
# 	 num cars in each lane [ 62.  81.  95. 124.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  441, average speed 5.24, flow in 1.86 vehicle/s, flow out 0.08 vehicle/s
# 	 num cars in each lane [ 81. 103. 115. 142.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  469, average speed 5.22, flow in 1.86 vehicle/s, flow out 1.30 vehicle/s
# 	 num cars in each lane [ 85. 110. 122. 152.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 350.00
# total vehicle:  465, average speed 5.21, flow in 1.86 vehicle/s, flow out 1.30 vehicle/s
# 	 num cars in each lane [ 91. 107. 124. 143.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  468, average speed 5.21, flow in 1.86 vehicle/s, flow out 1.80 vehicle/s
# 	 num cars in each lane [ 92. 101. 129. 146.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 450.00
# total vehicle:  467, average speed 5.20, flow in 1.86 vehicle/s, flow out 1.80 vehicle/s
# 	 num cars in each lane [ 85. 105. 130. 147.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  462, average speed 5.20, flow in 1.86 vehicle/s, flow out 1.96 vehicle/s
# 	 num cars in each lane [ 86. 108. 118. 150.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 550.00
# total vehicle:  467, average speed 5.21, flow in 1.86 vehicle/s, flow out 1.96 vehicle/s
# 	 num cars in each lane [ 81. 113. 127. 146.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 600.00
# total vehicle:  472, average speed 5.21, flow in 1.88 vehicle/s, flow out 1.78 vehicle/s
# 	 num cars in each lane [ 89. 105. 130. 148.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 650.00
# total vehicle:  470, average speed 5.21, flow in 1.88 vehicle/s, flow out 1.78 vehicle/s
# 	 num cars in each lane [ 96. 102. 124. 148.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 700.00
# total vehicle:  473, average speed 5.21, flow in 1.84 vehicle/s, flow out 1.78 vehicle/s
# 	 num cars in each lane [ 94. 107. 124. 148.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  464, average speed 5.21, flow in 1.84 vehicle/s, flow out 1.78 vehicle/s
# 	 num cars in each lane [ 87. 103. 132. 142.]
# -----------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-23775da5a755> in <module>()
#      11
#      12 for i in range(1, int(3600 / dt)):
# ---> 13     road.update(flow_in)
#      14     speed_avg.append(np.mean([car.vel for car in road.street]))
#      15     if i % 100 == 0:
#
# E:\File\竞赛\MCM\2017MCM\C\code\traffic_simulation\src\Street.py in update(self, q_in)
#      36         #self.assertion() # debug
#      37         self.insert_BC() # add boundary
# ---> 38         self.accelerate() # calculate new velocity
#      39         self.change_lanes()
#      40         self.clear_BC() # remove boundary
#
# E:\File\竞赛\MCM\2017MCM\C\code\traffic_simulation\src\Street.py in accelerate(self)
#     144         for idx in range(len(self.street)):
#     145             fwd = self.next_index_on_lane(self.street[idx].lane, idx)
# --> 146             self.street[idx].acceleration(self.street[fwd])
#     147         for car in self.street:
#     148             car.accelerate(self.dt)
#
# E:\File\竞赛\MCM\2017MCM\C\code\traffic_simulation\src\Cars.py in acceleration(self, fwd)
#      65             return self.acc
#      66         else:
# ---> 67             return self.model.calc_acc(self, fwd)
#      68
#      69     def distance_to(self, fwd):
#
# E:\File\竞赛\MCM\2017MCM\C\code\traffic_simulation\src\IDM.py in calc_acc(self, bwd, fwd)
#     103                         + (vel * delta_v) / (2 * self.sqrtab)
#     104         s_star = max(s_star_raw, self.s0)
# --> 105         acc = self.a * (1 - np.power(vel / self.v0, self.delta) - (s_star **2) / (s**2))
#     106         acc = max(acc, -MAIN_BSAVE)
#     107         return acc
#
# KeyboardInterrupt:

# %%
mean_speed = np.mean(speed_avg)

# %%
mean_speed * 3.6
# Out:
# 18.900103526490913

# %% [markdown]
# ## Experiment 2: Relationship: Auto car ratio v.s. Average speed
#
# change the ratio of AutoCar, and look for the average speed change
#
# * car_prob = 0.8
#
# * speed_limit = 60 MPH = 96 KMH
#
# * flow_in = 1.31 v/s = 4725 v/h
#
# * flow_in_ramp = 0.44 v/s = 1575 v/h
#
# * flow_in_total = 1.75 v/s = 6300 v/h
#
# * mile_post_dist = 0.821 mile = 1.31 km

# %%
def speed_auto(auto, num_lane):
    prob_auto, prob_car = auto, 0.8
    flow_in = 1.31
    road_length = 1310
    dt = 0.5
    prob_ramp = 0.25

    cf = CarFactory(prob_auto, prob_car)
    road = StreetRamp(num_lane, road_length, cf, prob_ramp, dt=dt)
    speed_avg = []

    for i in range(1, int(500 / dt)):
        road.update(flow_in)
        speed_avg.append(np.mean([car.vel for car in road.street]))
        if i % 500 == 0:
            road.report()
#         if i % 400 == 0:
#             fig = generate_fig(road)
#             plot(fig, image='png', filename='image{:04d}.html'.format(int(i/400)), image_filename='image{:04d}'.format(int(i/400)))
    return np.mean(speed_avg)

# %%
auto_ratio = np.arange(0, 1.01, 0.1)
performance3 = []
for auto in auto_ratio:
    print("############################################")
    print("auto car ratio = {:2.2f}".format(auto))
    print("############################################")
    performance3.append(speed_auto(auto, 3))
# Out:
# ############################################
# auto car ratio = 0.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  448, average speed 5.24, flow in 7.52 vehicle/s, flow out 0.30 vehicle/s
# 	 num cars in each lane [ 84. 103. 124. 137.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  464, average speed 5.20, flow in 9.28 vehicle/s, flow out 8.96 vehicle/s
# 	 num cars in each lane [ 90. 103. 124. 147.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  465, average speed 5.20, flow in 7.38 vehicle/s, flow out 7.38 vehicle/s
# 	 num cars in each lane [ 85. 103. 125. 152.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.10
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  436, average speed 5.97, flow in 8.16 vehicle/s, flow out 0.84 vehicle/s
# 	 num cars in each lane [ 82.  91. 122. 141.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  461, average speed 6.14, flow in 10.36 vehicle/s, flow out 9.86 vehicle/s
# 	 num cars in each lane [ 88. 108. 125. 140.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  449, average speed 5.97, flow in 8.10 vehicle/s, flow out 8.68 vehicle/s
# 	 num cars in each lane [ 85. 102. 114. 148.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.20
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  426, average speed 6.36, flow in 9.14 vehicle/s, flow out 1.72 vehicle/s
# 	 num cars in each lane [ 69.  92. 117. 148.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  438, average speed 6.91, flow in 11.54 vehicle/s, flow out 11.30 vehicle/s
# 	 num cars in each lane [ 75.  94. 117. 152.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  441, average speed 6.86, flow in 9.00 vehicle/s, flow out 9.20 vehicle/s
# 	 num cars in each lane [ 80.  99. 113. 149.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.30
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  384, average speed 7.43, flow in 9.88 vehicle/s, flow out 3.44 vehicle/s
# 	 num cars in each lane [ 65.  82. 103. 134.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  443, average speed 7.83, flow in 12.66 vehicle/s, flow out 11.48 vehicle/s
# 	 num cars in each lane [ 72.  98. 124. 149.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  435, average speed 7.42, flow in 10.10 vehicle/s, flow out 10.30 vehicle/s
# 	 num cars in each lane [ 79.  92. 113. 151.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.40
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  273, average speed 13.50, flow in 10.44 vehicle/s, flow out 5.20 vehicle/s
# 	 num cars in each lane [ 18.  53.  78. 124.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  291, average speed 11.72, flow in 13.10 vehicle/s, flow out 12.74 vehicle/s
# 	 num cars in each lane [ 25.  48.  85. 133.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  296, average speed 11.81, flow in 10.48 vehicle/s, flow out 10.38 vehicle/s
# 	 num cars in each lane [ 30.  49.  79. 138.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.50
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  248, average speed 13.89, flow in 10.44 vehicle/s, flow out 5.82 vehicle/s
# 	 num cars in each lane [ 14.  46.  68. 120.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  235, average speed 14.54, flow in 13.10 vehicle/s, flow out 13.36 vehicle/s
# 	 num cars in each lane [  9.  49.  64. 113.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  249, average speed 13.38, flow in 10.48 vehicle/s, flow out 10.54 vehicle/s
# 	 num cars in each lane [ 14.  39.  74. 122.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.60
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  195, average speed 16.98, flow in 10.44 vehicle/s, flow out 6.66 vehicle/s
# 	 num cars in each lane [10. 36. 57. 92.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  214, average speed 16.20, flow in 13.10 vehicle/s, flow out 12.72 vehicle/s
# 	 num cars in each lane [ 12.  33.  55. 114.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  204, average speed 17.30, flow in 10.48 vehicle/s, flow out 10.64 vehicle/s
# 	 num cars in each lane [19. 36. 52. 97.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.70
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  180, average speed 19.73, flow in 10.44 vehicle/s, flow out 6.90 vehicle/s
# 	 num cars in each lane [20. 37. 51. 72.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  189, average speed 17.73, flow in 13.10 vehicle/s, flow out 12.92 vehicle/s
# 	 num cars in each lane [10. 30. 55. 94.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  184, average speed 18.73, flow in 10.48 vehicle/s, flow out 10.64 vehicle/s
# 	 num cars in each lane [14. 40. 52. 78.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.80
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  166, average speed 20.96, flow in 10.44 vehicle/s, flow out 7.32 vehicle/s
# 	 num cars in each lane [16. 35. 45. 70.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  161, average speed 20.98, flow in 13.10 vehicle/s, flow out 13.20 vehicle/s
# 	 num cars in each lane [13. 45. 37. 66.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  160, average speed 21.82, flow in 10.48 vehicle/s, flow out 10.56 vehicle/s
# 	 num cars in each lane [19. 36. 40. 65.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.90
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  152, average speed 23.12, flow in 10.44 vehicle/s, flow out 7.50 vehicle/s
# 	 num cars in each lane [ 2. 39. 43. 68.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  144, average speed 23.38, flow in 13.10 vehicle/s, flow out 13.26 vehicle/s
# 	 num cars in each lane [ 3. 32. 60. 49.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  143, average speed 24.18, flow in 10.48 vehicle/s, flow out 10.40 vehicle/s
# 	 num cars in each lane [ 5. 15. 56. 67.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 1.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  133, average speed 26.14, flow in 10.44 vehicle/s, flow out 7.82 vehicle/s
# 	 num cars in each lane [ 2.  8. 53. 70.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 500.00
# total vehicle:  132, average speed 26.18, flow in 13.10 vehicle/s, flow out 13.12 vehicle/s
# 	 num cars in each lane [ 3.  6. 43. 80.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 750.00
# total vehicle:  132, average speed 26.08, flow in 10.48 vehicle/s, flow out 10.50 vehicle/s
# 	 num cars in each lane [ 3. 15. 36. 78.]
# -----------------------------------------------------------------

# %%
def speed_auto_dedicate(auto, num_lane):
    prob_auto, prob_car = auto, 0.8
    flow_in = 1.31
    road_length = 1310
    dt = 0.5
    prob_ramp = 0.25

    road = StreetAuto(num_lane, road_length, prob_auto, prob_ramp, dt=dt)
    speed_avg = []

    for i in range(1, int(500 / dt)):
        road.update(flow_in)
        avg1 = np.sum([car.vel for car in road.main_road.street])
        avg2 = np.sum([car.vel for car in road.auto_road.street])
        avg = (avg1 + avg2)/(1+len(road.main_road.street) + len(road.auto_road.street))
        if i % 500 == 0:
            road.report()
#         if i % 400 == 0:
#             fig = generate_fig(road)
#             plot(fig, image='png', filename='image{:04d}.html'.format(int(i/400)), image_filename='image{:04d}'.format(int(i/400)))
    return avg

# %%
auto_ratio = np.arange(0, 1.01, 0.1)
performance3_dedicate = []
for auto in auto_ratio:
    print("############################################")
    print("auto car ratio = {:2.2f}".format(auto))
    print("############################################")
    performance3_dedicate.append(speed_auto_dedicate(auto, 3))
# Out:
# ############################################
# auto car ratio = 0.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  332, average speed 5.18
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.10
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  343, average speed 5.98
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.20
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  351, average speed 6.74
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.30
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  356, average speed 8.38
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.40
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  337, average speed 9.40
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.50
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  247, average speed 13.75
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.60
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  162, average speed 20.95
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.70
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  137, average speed 24.88
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.80
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  135, average speed 25.58
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.90
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  134, average speed 25.63
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 1.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  132, average speed 25.71
# -----------------------------------------------------------------

# %%
plt.plot(auto_ratio, performance3, label='no dedicate lanes')
plt.plot(auto_ratio, performance3_dedicate, label='with dedicate lanes')
plt.title('3 main lane + 1 on ramp')
plt.xlabel('autonomous car ratio')
plt.ylabel('average speed (m/s)')
plt.legend()

# %%
auto_ratio = np.arange(0, 1.01, 0.1)
performance2 = []
for auto in auto_ratio:
    print("############################################")
    print("auto car ratio = {:2.2f}".format(auto))
    print("############################################")
    performance2.append(speed_auto(auto, 2))
# Out:
# ############################################
# auto car ratio = 0.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  332, average speed 5.24, flow in 5.64 vehicle/s, flow out 0.18 vehicle/s
# 	 num cars in each lane [ 93. 111. 128.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.10
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  330, average speed 6.22, flow in 6.38 vehicle/s, flow out 0.66 vehicle/s
# 	 num cars in each lane [ 95. 107. 128.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.20
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  338, average speed 7.27, flow in 6.88 vehicle/s, flow out 1.28 vehicle/s
# 	 num cars in each lane [ 90. 108. 140.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.30
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  299, average speed 7.80, flow in 7.74 vehicle/s, flow out 2.22 vehicle/s
# 	 num cars in each lane [ 79.  97. 123.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.40
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  301, average speed 8.60, flow in 8.26 vehicle/s, flow out 2.98 vehicle/s
# 	 num cars in each lane [ 70.  98. 133.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.50
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  264, average speed 10.53, flow in 9.02 vehicle/s, flow out 3.82 vehicle/s
# 	 num cars in each lane [ 55.  85. 124.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.60
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  244, average speed 12.67, flow in 9.94 vehicle/s, flow out 5.12 vehicle/s
# 	 num cars in each lane [ 43.  82. 119.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.70
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  223, average speed 15.33, flow in 10.40 vehicle/s, flow out 6.16 vehicle/s
# 	 num cars in each lane [ 49.  73. 101.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.80
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  182, average speed 19.52, flow in 10.44 vehicle/s, flow out 7.08 vehicle/s
# 	 num cars in each lane [44. 57. 81.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.90
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  156, average speed 21.99, flow in 10.44 vehicle/s, flow out 7.44 vehicle/s
# 	 num cars in each lane [41. 50. 65.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 1.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  132, average speed 25.99, flow in 10.44 vehicle/s, flow out 7.78 vehicle/s
# 	 num cars in each lane [11. 46. 75.]
# -----------------------------------------------------------------

# %%
auto_ratio = np.arange(0, 1.01, 0.1)
performance2_dedicate = []
for auto in auto_ratio:
    print("############################################")
    print("auto car ratio = {:2.2f}".format(auto))
    print("############################################")
    performance2_dedicate.append(speed_auto_dedicate(auto, 2))
# Out:
# ############################################
# auto car ratio = 0.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  224, average speed 5.18
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.10
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  238, average speed 6.31
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.20
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  240, average speed 7.52
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.30
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  223, average speed 10.28
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.40
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  229, average speed 11.47
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.50
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  221, average speed 12.52
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.60
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  221, average speed 14.06
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.70
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  224, average speed 15.39
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.80
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  134, average speed 25.59
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.90
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  135, average speed 25.56
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 1.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  134, average speed 25.77
# -----------------------------------------------------------------

# %%
plt.plot(auto_ratio, performance2, label='no dedicate lanes')
plt.plot(auto_ratio, performance2_dedicate, label='with dedicate lanes')
plt.title('2 main lane + 1 on ramp')
plt.xlabel('autonomous car ratio')
plt.ylabel('average speed (m/s)')
plt.legend()

# %%
auto_ratio = np.arange(0, 1.01, 0.1)
performance4 = []
for auto in auto_ratio:
    print("############################################")
    print("auto car ratio = {:2.2f}".format(auto))
    print("############################################")
    performance4.append(speed_auto(auto, 4))
# Out:
# ############################################
# auto car ratio = 0.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  538, average speed 5.22, flow in 9.32 vehicle/s, flow out 0.68 vehicle/s
# 	 num cars in each lane [ 69.  90. 102. 126. 151.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.10
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  447, average speed 7.83, flow in 10.14 vehicle/s, flow out 2.30 vehicle/s
# 	 num cars in each lane [ 30.  57.  88. 116. 156.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.20
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  311, average speed 10.83, flow in 10.46 vehicle/s, flow out 4.22 vehicle/s
# 	 num cars in each lane [  8.  38.  58.  80. 127.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.30
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  247, average speed 14.00, flow in 10.44 vehicle/s, flow out 5.60 vehicle/s
# 	 num cars in each lane [ 13.  24.  38.  58. 114.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.40
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  234, average speed 15.15, flow in 10.44 vehicle/s, flow out 5.82 vehicle/s
# 	 num cars in each lane [  6.  26.  36.  62. 104.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.50
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  199, average speed 15.92, flow in 10.44 vehicle/s, flow out 6.70 vehicle/s
# 	 num cars in each lane [ 6. 28. 35. 49. 81.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.60
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  185, average speed 19.22, flow in 10.44 vehicle/s, flow out 6.82 vehicle/s
# 	 num cars in each lane [ 6. 42. 25. 34. 78.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.70
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  175, average speed 19.81, flow in 10.44 vehicle/s, flow out 7.12 vehicle/s
# 	 num cars in each lane [ 2. 33. 35. 36. 69.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.80
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  157, average speed 21.97, flow in 10.44 vehicle/s, flow out 7.46 vehicle/s
# 	 num cars in each lane [ 2. 14. 30. 54. 57.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.90
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  142, average speed 24.16, flow in 10.44 vehicle/s, flow out 7.62 vehicle/s
# 	 num cars in each lane [ 2.  9. 16. 53. 62.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 1.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  132, average speed 26.15, flow in 10.44 vehicle/s, flow out 7.78 vehicle/s
# 	 num cars in each lane [ 2.  4. 16. 35. 75.]
# -----------------------------------------------------------------

# %%
auto_ratio = np.arange(0, 1.01, 0.1)
performance4_dedicate = []
for auto in auto_ratio:
    print("############################################")
    print("auto car ratio = {:2.2f}".format(auto))
    print("############################################")
    performance4_dedicate.append(speed_auto_dedicate(auto, 4))
# Out:
# ############################################
# auto car ratio = 0.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  443, average speed 5.21
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.10
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  452, average speed 5.83
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.20
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  458, average speed 6.42
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.30
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  271, average speed 12.94
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.40
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  204, average speed 16.66
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.50
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  170, average speed 19.65
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.60
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  152, average speed 23.40
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.70
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  138, average speed 25.39
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.80
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  138, average speed 25.67
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.90
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  135, average speed 25.66
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 1.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  134, average speed 25.47
# -----------------------------------------------------------------

# %%
plt.plot(auto_ratio, performance4, label='no dedicate lanes')
plt.plot(auto_ratio, performance4_dedicate, label='with dedicate lanes')
plt.title('4 main lane + 1 on ramp')
plt.xlabel('autonomous car ratio')
plt.ylabel('average speed (m/s)')
plt.legend()

# %%
auto_ratio = np.arange(0, 1.01, 0.1)
performance5 = []
for auto in auto_ratio:
    print("############################################")
    print("auto car ratio = {:2.2f}".format(auto))
    print("############################################")
    performance5.append(speed_auto(auto, 5))
# Out:
# ############################################
# auto car ratio = 0.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  381, average speed 8.80, flow in 10.20 vehicle/s, flow out 3.34 vehicle/s
# 	 num cars in each lane [  4.  24.  50.  73.  91. 139.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.10
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  342, average speed 10.47, flow in 10.44 vehicle/s, flow out 4.12 vehicle/s
# 	 num cars in each lane [  7.  24.  38.  64.  86. 123.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.20
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  250, average speed 14.14, flow in 10.44 vehicle/s, flow out 5.22 vehicle/s
# 	 num cars in each lane [  2.  15.  27.  39.  63. 104.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.30
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  237, average speed 14.15, flow in 10.44 vehicle/s, flow out 5.60 vehicle/s
# 	 num cars in each lane [  5.  12.  27.  36.  53. 104.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.40
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  221, average speed 15.49, flow in 10.44 vehicle/s, flow out 6.12 vehicle/s
# 	 num cars in each lane [  3.  19.  21.  27.  48. 103.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.50
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  180, average speed 18.59, flow in 10.44 vehicle/s, flow out 6.74 vehicle/s
# 	 num cars in each lane [ 2. 18. 28. 25. 40. 67.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.60
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  165, average speed 20.06, flow in 10.44 vehicle/s, flow out 7.18 vehicle/s
# 	 num cars in each lane [ 2. 15. 20. 35. 31. 62.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.70
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  173, average speed 20.15, flow in 10.44 vehicle/s, flow out 7.02 vehicle/s
# 	 num cars in each lane [ 2.  6. 30. 40. 39. 56.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.80
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  150, average speed 23.29, flow in 10.44 vehicle/s, flow out 7.34 vehicle/s
# 	 num cars in each lane [ 2.  1. 12. 31. 49. 55.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.90
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  142, average speed 24.86, flow in 10.44 vehicle/s, flow out 7.64 vehicle/s
# 	 num cars in each lane [ 2.  1.  7. 24. 47. 61.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 1.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  133, average speed 26.11, flow in 10.44 vehicle/s, flow out 7.82 vehicle/s
# 	 num cars in each lane [ 2.  1.  3. 15. 44. 68.]
# -----------------------------------------------------------------

# %%
auto_ratio = np.arange(0, 1.01, 0.1)
performance5_dedicate = []
for auto in auto_ratio:
    print("############################################")
    print("auto car ratio = {:2.2f}".format(auto))
    print("############################################")
    performance5_dedicate.append(speed_auto_dedicate(auto, 5))
# Out:
# ############################################
# auto car ratio = 0.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  544, average speed 5.20
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.10
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  415, average speed 8.15
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.20
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  263, average speed 13.50
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.30
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  209, average speed 16.75
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.40
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  179, average speed 20.69
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.50
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  150, average speed 20.67
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.60
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  147, average speed 23.94
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.70
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  136, average speed 25.43
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.80
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  134, average speed 25.68
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 0.90
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  134, average speed 25.48
# -----------------------------------------------------------------
# ############################################
# auto car ratio = 1.00
# ############################################
# -----------------------------------------------------------------
# time = 250.00
# total vehicle:  133, average speed 25.70
# -----------------------------------------------------------------

# %%
plt.plot(auto_ratio, performance5, label='no dedicate lanes')
plt.plot(auto_ratio, performance5_dedicate, label='with dedicate lanes')
plt.title('5 main lane + 1 on ramp')
plt.xlabel('autonomous car ratio')
plt.ylabel('average speed (m/s)')
plt.legend()

# %% [markdown]
# ## Experiment 3: average speed v.s. number of lanes

# %%
def speed_human_lane(lane):
    prob_auto, prob_car = 0, 0.8
    flow_in = 1.31
    road_length = 1310
    dt = 0.5
    prob_ramp = 0.25
    num_lane = lane

    cf = CarFactory(prob_auto, prob_car)
    road = StreetRamp(num_lane, road_length, cf, prob_ramp, dt=dt)
    speed_avg = []

    for i in range(1, int(500 / dt)):
        road.update(flow_in)
        speed_avg.append(np.mean([car.vel for car in road.street]))
        if i % 200 == 0:
            road.report()
    return np.mean(speed_avg)

# %%
lanes = [1,2,3,4,5,6,7,8]
performance_lane = []
for lane in lanes:
    print("############################################")
    print("auto car ratio = {:2d}".format(lane))
    print("############################################")
    performance_lane.append(speed_human_lane(lane))
# Out:
# ############################################
# auto car ratio =  1
# ############################################
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:   92, average speed 5.39, flow in 1.92 vehicle/s, flow out 0.10 vehicle/s
# 	 num cars in each lane [38. 54.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  183, average speed 5.27, flow in 1.86 vehicle/s, flow out 0.04 vehicle/s
# 	 num cars in each lane [86. 97.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  233, average speed 5.19, flow in 1.86 vehicle/s, flow out 0.86 vehicle/s
# 	 num cars in each lane [105. 128.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  232, average speed 5.17, flow in 1.84 vehicle/s, flow out 1.86 vehicle/s
# 	 num cars in each lane [110. 122.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio =  2
# ############################################
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:  139, average speed 5.43, flow in 2.86 vehicle/s, flow out 0.10 vehicle/s
# 	 num cars in each lane [36. 46. 57.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  275, average speed 5.30, flow in 2.78 vehicle/s, flow out 0.06 vehicle/s
# 	 num cars in each lane [ 70.  94. 111.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  346, average speed 5.23, flow in 2.78 vehicle/s, flow out 1.36 vehicle/s
# 	 num cars in each lane [ 95. 114. 137.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  348, average speed 5.20, flow in 2.78 vehicle/s, flow out 2.74 vehicle/s
# 	 num cars in each lane [ 97. 110. 141.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio =  3
# ############################################
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:  181, average speed 5.38, flow in 3.80 vehicle/s, flow out 0.20 vehicle/s
# 	 num cars in each lane [29. 41. 52. 59.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  363, average speed 5.24, flow in 3.72 vehicle/s, flow out 0.08 vehicle/s
# 	 num cars in each lane [ 63.  75.  98. 127.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  468, average speed 5.19, flow in 3.68 vehicle/s, flow out 1.58 vehicle/s
# 	 num cars in each lane [ 91. 104. 128. 145.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  471, average speed 5.20, flow in 3.74 vehicle/s, flow out 3.68 vehicle/s
# 	 num cars in each lane [ 86. 110. 121. 154.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio =  4
# ############################################
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:  227, average speed 5.74, flow in 4.76 vehicle/s, flow out 0.24 vehicle/s
# 	 num cars in each lane [32. 33. 40. 55. 67.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  437, average speed 5.23, flow in 4.62 vehicle/s, flow out 0.42 vehicle/s
# 	 num cars in each lane [ 54.  70.  83. 105. 125.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  576, average speed 5.18, flow in 4.60 vehicle/s, flow out 1.82 vehicle/s
# 	 num cars in each lane [ 77.  95. 115. 129. 160.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  591, average speed 5.19, flow in 4.66 vehicle/s, flow out 4.36 vehicle/s
# 	 num cars in each lane [ 76.  98. 122. 133. 162.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio =  5
# ############################################
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:  231, average speed 8.62, flow in 5.06 vehicle/s, flow out 0.46 vehicle/s
# 	 num cars in each lane [10. 17. 27. 38. 60. 79.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  390, average speed 8.42, flow in 5.04 vehicle/s, flow out 1.86 vehicle/s
# 	 num cars in each lane [  4.  22.  46.  68.  98. 152.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  428, average speed 8.49, flow in 5.12 vehicle/s, flow out 4.36 vehicle/s
# 	 num cars in each lane [ 14.  33.  50.  76. 100. 155.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  399, average speed 8.04, flow in 5.14 vehicle/s, flow out 5.72 vehicle/s
# 	 num cars in each lane [  9.  30.  49.  79.  90. 142.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio =  6
# ############################################
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:  216, average speed 11.90, flow in 5.20 vehicle/s, flow out 0.90 vehicle/s
# 	 num cars in each lane [ 6.  7. 14. 20. 40. 53. 76.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  306, average speed 10.49, flow in 5.26 vehicle/s, flow out 3.46 vehicle/s
# 	 num cars in each lane [  5.   9.  18.  32.  50.  77. 115.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  336, average speed 9.69, flow in 5.22 vehicle/s, flow out 4.62 vehicle/s
# 	 num cars in each lane [  4.  11.  20.  38.  66.  79. 118.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  349, average speed 9.27, flow in 5.18 vehicle/s, flow out 4.92 vehicle/s
# 	 num cars in each lane [  3.  13.  25.  37.  61.  82. 128.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio =  7
# ############################################
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:  204, average speed 12.60, flow in 5.20 vehicle/s, flow out 1.14 vehicle/s
# 	 num cars in each lane [ 2.  7. 10. 11. 21. 36. 50. 67.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  302, average speed 10.95, flow in 5.26 vehicle/s, flow out 3.30 vehicle/s
# 	 num cars in each lane [  3.   4.  10.  16.  32.  50.  66. 121.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  311, average speed 10.86, flow in 5.24 vehicle/s, flow out 5.06 vehicle/s
# 	 num cars in each lane [  3.   7.  14.  20.  31.  45.  71. 120.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  306, average speed 10.62, flow in 5.24 vehicle/s, flow out 5.34 vehicle/s
# 	 num cars in each lane [  4.   4.  12.  21.  30.  45.  70. 120.]
# -----------------------------------------------------------------
# ############################################
# auto car ratio =  8
# ############################################
# -----------------------------------------------------------------
# time = 100.00
# total vehicle:  200, average speed 14.99, flow in 5.22 vehicle/s, flow out 1.24 vehicle/s
# 	 num cars in each lane [ 3.  2.  5.  6. 11. 18. 28. 45. 82.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 200.00
# total vehicle:  242, average speed 12.58, flow in 5.24 vehicle/s, flow out 4.40 vehicle/s
# 	 num cars in each lane [ 3.  1.  1.  8. 16. 24. 39. 59. 91.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 300.00
# total vehicle:  281, average speed 13.05, flow in 5.24 vehicle/s, flow out 4.46 vehicle/s
# 	 num cars in each lane [  2.   2.   7.  13.  20.  24.  41.  62. 110.]
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# time = 400.00
# total vehicle:  265, average speed 11.77, flow in 5.24 vehicle/s, flow out 5.56 vehicle/s
# 	 num cars in each lane [  3.   1.   5.  11.  20.  27.  41.  56. 101.]
# -----------------------------------------------------------------

# %%
plt.plot(lanes, performance_lane)
plt.title('performance v.s. number of lanes')
plt.xlabel('number of lanes')
plt.ylabel('average speed (m/s)')
plt.axhline(y=25, color='r', linestyle='--')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Experiment 4: Snapshot on the point of intersection (dedicate lane v.s. mixed)

# %%
## no dedicate lane
prob_auto, prob_car = 0.38, 0.8
flow_in = 1.31
road_length = 1310
dt = 0.5
prob_ramp = 0.25
num_lane = 4

cf = CarFactory(prob_auto, prob_car)
road = StreetRamp(num_lane, road_length, cf, prob_ramp, dt=dt)

for i in range(1, int(250 / dt)):
    road.update(flow_in)

# %%
fig = generate_fig(road)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~horacehxw2/220.embed" height="525px" width="100%"></iframe>

# %%
prob_auto, prob_car = 0.38, 0.8
flow_in = 1.31
road_length = 1310
dt = 0.5
prob_ramp = 0.25
num_lane = 4

road = StreetAuto(num_lane, road_length, prob_auto, prob_ramp, dt=dt)
speed_avg = []

for i in range(1, int(250 / dt)):
    road.update(flow_in)

# %%
road1 = road.main_road
road2 = road.auto_road

traces = []
for car in road1.street:
    trace = go.Scatter(x = [car.pos, car.pos+car.length],
                       y = [car.lane + 1, car.lane + 1],
                       mode = 'lines',
                       marker = dict( color = color_map['{}'.format(int(car.vel / (5.5)))]
                                       ))
    traces.append(trace)
    
for car in road2.street:
    trace = go.Scatter(x = [car.pos, car.pos+car.length],
                       y = [-car.lane + 2 + 4, -car.lane + 2 + 4],
                       mode = 'lines',
                       marker = dict( color = color_map['{}'.format(int(car.vel / (5.5)))]
                                       ))
    traces.append(trace)
    
# lane seperation
trace = go.Scatter(x = [0, road.main_road.road_length],
                   y = [4.5, 4.5],
                   mode = 'lines',
                   marker = dict( color = 'rgb(0,0,0)')
                  )
traces.append(trace)
                                    

layout = go.Layout(title='traffic simulation at time {:6.1f}s'.format(road.main_road.time),
                   xaxis=dict(title='distance (meters)'),
                   yaxis=dict(title='lane number',
                                showgrid=True,
                                zeroline=False,
                                showline=False,
                                showticklabels=True),
                   showlegend=False)
fig = go.Figure(data= traces, layout=layout)

# %%
py.iplot(fig)
